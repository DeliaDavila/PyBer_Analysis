# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
#change figure size
#plt.figure(figsize=(20,10))
plt.subplots(figsize=(20,10))

# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0,45)
# playing with xlim
# plt.xlim("Jan","June")

# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
month = ["Jawn", "Ferb", "Marw", "Aprao", "Mao", "Juao", "Jlyo", "Agao", "Spt", "Ocat"]

# Set the y-axis to a list of floats in US dollars accumulated for each month.

numMeow = [2.6, 5.5, 15.7, 7.4, 8.9, 6.1, 9.8, 10.1, 4.5, 7.7]

# Create the plot.
plt.plot(month, numMeow, color="green", marker="D", label="Catty")
# Create labels for the x and y axes.
plt.xlabel("Months in cat")
plt.ylabel("Meows")

# Set the y limit
plt.ylim(0, 18)

# Create a title.
plt.title("Cats meowing in the night (monthly)")

# Add a grid.
plt.grid()

# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# skill drill
#Change the bar colors to magenta.
plt.barh(x_axis, y_axis, color="magenta", label="Boston")

#Add a legend for the city of Boston.
plt.legend()

#Add a title and axes labels.
plt.title("What up?")
plt.xlabel("fare")
plt.ylabel("month")
#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
xmen = ["Xavier", "Storm", "Wolverine"]
yolo = [1, 2, 5]

plt.barh(xmen, yolo)
#so the "y axis" of a horizontal comes first. bar(y,x)

plt.title("How many fucks given?")
plt.xlabel("YOLOs")
plt.ylabel("Xmen for X axis")
# Out:
# Text(0, 0.5, 'Xmen for X axis')

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#skill drill
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label="Chicago")
ax.set_title("Woof")
ax.set_ylabel("yyyy")
ax.set_xlabel("xxx")
ax.legend()
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

plt.plot(x_axis, y_axis, 'o')
#plt.scatter(x_axis, y_axis)

# %%
#skill drill
plt.scatter(y_axis, x_axis, color="red", label="Chicago")
plt.xlabel("fare")
plt.ylabel("mo")
plt.title("yum")
plt.xlim(0,50)
plt.gca().invert_yaxis()

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
#skill drill
fig, ax = plt.subplots()
#ax.scatter(x_axis, y_axis, s=[i*5 for i in y_axis], color="skyblue", label="Boston")

#ax.scatter(x_axis, y_axis, alpha = 1)
ax.scatter(x_axis, y_axis, s=[i*8 for i in y_axis], alpha=.4, linewidth=2, edgecolors="black")

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
plt.show()

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
plt.show()

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
fix,ax=plt.subplots()
ax.pie(y_axis, labels=x_axis)
plt.show()

# %%
#skill drill
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

fig,ax=plt.subplots(figsize=(8,8))
ax.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    shadow=True,
    startangle = 90,
    counterclock = False,
    autopct="%1.1f%%")

plt.show()
